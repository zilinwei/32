# %% [markdown]
# <a href="https://colab.research.google.com/github/zilinwei/32/blob/main/%E4%BD%9C%E6%A5%AD5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt


def equation(x, a, b, c):
    return a * x**2 + b * x + c


x = np.linspace(1, 150, 150)  


a = -2
b = 4
c = 5


y = equation(x, a, b, c)


plt.plot(x, y, label='Equation')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Equation Graph')
plt.grid(True)

plt.axhline(0, color='black', linewidth=0.5)  


max_index = np.argmax(y)
min_index = np.argmin(y)
max_x = x[max_index]
max_y = y[max_index]
min_x = x[min_index]
min_y = y[min_index]
plt.plot(max_x, max_y, 'ro', label=f'Highest Point ({round(max_x)}, {round(max_y)})')
plt.plot(min_x, min_y, 'go', label=f'Lowest Point ({round(min_x)}, {round(min_y)})')
plt.text(max_x, max_y, f'({round(max_x)}, {round(max_y)})', verticalalignment='bottom')
plt.text(min_x, min_y, f'({round(min_x)}, {round(min_y)})', verticalalignment='top')

zero_indices = np.where(np.isclose(y, 0, atol=1e-6))[0]
zero_x = x[zero_indices]
zero_y = y[zero_indices]
plt.plot(zero_x, zero_y, 'bo', label='Intersection with x-axis')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def equation(x, a, b, c):
    return a * x**2 + b * x + c


x = np.linspace(1, 150, 150)  


a = 3
b = 2
c = -6


y = equation(x, a, b, c)


plt.plot(x, y, label='Equation')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Equation Graph')
plt.grid(True)

plt.axhline(0, color='black', linewidth=0.5) 

max_index = np.argmax(y)
min_index = np.argmin(y)
max_x = x[max_index]
max_y = y[max_index]
min_x = x[min_index]
min_y = y[min_index]
plt.plot(max_x, max_y, 'ro', label=f'Highest Point ({round(max_x)}, {round(max_y)})')
plt.plot(min_x, min_y, 'go', label=f'Lowest Point ({round(min_x)}, {round(min_y)})')
plt.text(max_x, max_y, f'({round(max_x)}, {round(max_y)})', verticalalignment='bottom')
plt.text(min_x, min_y, f'({round(min_x)}, {round(min_y)})', verticalalignment='top')

zero_indices = np.where(np.isclose(y, 0, atol=1e-6))[0]
zero_x = x[zero_indices]
zero_y = y[zero_indices]
plt.plot(zero_x, zero_y, 'bo', label='Intersection with x-axis')

plt.legend()
plt.show()
